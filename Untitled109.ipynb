# %% [markdown]
# <a href="https://colab.research.google.com/github/Gewissta/Streamlit_for_Data_Science/blob/main/Untitled109.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import re

# %%
current_time = datetime.now()
previous_day = current_time - timedelta(days=5)
previous_day = datetime(previous_day.year, previous_day.month, previous_day.day, 19, 0)
start_time = previous_day.strftime("%Y-%m-%dT%H")

# %%
response = requests.get(f"https://inkalika.99ns.ru/api/v1/treatments.json?find[created_at][$gte]={start_time}")
ins_lst = []
if response.status_code == 200:
    treatments_data = response.json()
    for i, x in enumerate(treatments_data):
        if x['eventType'] in ['Meal Bolus', 'Correction Bolus', 'Temp Basal']:
            time_obj = datetime.strptime(x['created_at'], "%Y-%m-%dT%H:%M:%S.%f%z")
            if 'rate' in x:
                ins_lst.append([time_obj, x['eventType'], x['insulin'], x['rate']])
            else:
                ins_lst.append([time_obj, x['eventType'], x['insulin'], None])

    df_ins = pd.DataFrame(ins_lst, columns=['Time', 'eventType', 'InsulinInjection', 'TBR'])
    df_ins.loc[df_ins['InsulinInjection'].isna(), 'InsulinInjection'] = 0
df_ins
# Out:
#                                 Time   eventType  InsulinInjection    TBR
# 0   2024-11-24 16:48:22.997000+00:00  Temp Basal               0.0  0.000
# 1   2024-11-24 16:46:30.290000+00:00  Temp Basal               0.0  0.000
# 2   2024-11-24 16:45:24.866000+00:00  Temp Basal               0.0  0.085
# 3   2024-11-24 16:42:31.197000+00:00  Temp Basal               0.0  0.187
# 4   2024-11-24 16:39:13.204000+00:00  Temp Basal               0.0  0.000
# ..                               ...         ...               ...    ...
# 769 2024-11-20 23:09:30.519000+00:00  Temp Basal               0.0  0.234
# 770 2024-11-20 22:59:23.470000+00:00  Temp Basal               0.0  0.144
# 771 2024-11-20 22:54:40.387000+00:00  Temp Basal               0.0  0.480
# 772 2024-11-20 22:51:29.086000+00:00  Temp Basal               0.0  0.384
# 773 2024-11-20 22:49:40.610000+00:00  Temp Basal               0.0  0.264
#
# [774 rows x 4 columns]

# %%
# Out:
#                          Time   eventType  InsulinInjection  TBR
# 23  2024-11-24 13:51:37+00:00  Meal Bolus               2.3  NaN
# 198 2024-11-23 13:22:07+00:00  Meal Bolus               2.2  NaN
# 227 2024-11-23 08:29:37+00:00  Meal Bolus               2.7  NaN
# 459 2024-11-22 08:53:06+00:00  Meal Bolus               2.6  NaN
# 644 2024-11-21 13:22:39+00:00  Meal Bolus               2.2  NaN
# 677 2024-11-21 08:12:53+00:00  Meal Bolus               2.7  NaN

# %%
            if pd.notnull(x['insulin']) or pd.notnull(x['carbs']):
                time_obj = datetime.strptime(x['created_at'], "%Y-%m-%dT%H:%M:%S.%f%z")
                ins_carb_lst.append([time_obj, x['insulin'], x['carbs']])
        df_ins_carbs = pd.DataFrame(ins_carb_lst, columns=['Time', 'InsulinInjection', 'Carbs'])
        df_ins_carbs['Time'] = df_ins_carbs['Time'] + pd.Timedelta(hours=5)
        df_ins_carbs['Date'] = df_ins_carbs['Time'].dt.date
        df_ins_carbs['Time'] = df_ins_carbs['Time'].dt.floor('s').dt.time
        df_ins_carbs = df_ins_carbs[['Date', 'Time', 'InsulinInjection', 'Carbs']]
        df_ins_carbs['DateTime'] = pd.to_datetime(df_ins_carbs['Date'].astype(str) + ' ' + df_ins_carbs['Time'].astype(str))
        df_ins_carbs['DateTime'] = df_ins_carbs['DateTime'].dt.floor('T')
        df_ins_carbs_agg = df_ins_carbs.groupby('DateTime').agg({
            'InsulinInjection': 'sum',
            'Carbs': 'sum'
        }).reset_index()
        df_ins_carbs_agg['Date'] = df_ins_carbs_agg['DateTime'].dt.date
        df_ins_carbs_agg['Time'] = df_ins_carbs_agg['DateTime'].dt.time
        #df_ins_carbs_agg = df_ins_carbs_agg.drop(columns=['DateTime'])
        df_ins_carbs_agg = df_ins_carbs_agg[['Date', 'Time', 'InsulinInjection', 'Carbs']]
